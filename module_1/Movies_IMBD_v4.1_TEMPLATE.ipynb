# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id    budget    revenue                  original_title  \
# 1870  tt0144528  84000000  123307945  Nutty Professor II: The Klumps
# 1541  tt0395495  25000000   16158487               Catch and Release
# 39    tt1618442  90000000  140396650           The Last Witch Hunter
# 246   tt1136608  30000000  210819611                      District 9
# 1263  tt0765446  40000000   74597643        Escape from Planet Earth
#
#                                                    cast        director  \
# 1870  Eddie Murphy|Janet Jackson|Larry Miller|John A...     Peter Segal
# 1541  Jennifer Garner|Timothy Olyphant|Kevin Smith|S...  Susannah Grant
# 39    Vin Diesel|Rose Leslie|Michael Caine|Elijah Wo...    Breck Eisner
# 246   Sharlto Copley|Jason Cope|Nathalie Boltt|Sylva...  Neill Blomkamp
# 1263  Brendan Fraser|Rob Corddry|Ricky Gervais|Jessi...  Callan Brunker
#
#                                                tagline  \
# 1870                              The Klumps are back!
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000
#
#        title_length  tagline_length        profit
# count   1889.000000     1889.000000  1.889000e+03
# mean      15.037057       37.819481  1.010545e+08
# std        8.552660       19.638813  1.830733e+08
# min        1.000000        3.000000 -1.657101e+08
# ...

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов
answers['1'] = 'Pirates of the Caribbean: On Stranger Tides (tt1298650) budget=380000000'
answers['2'] = 'Gods and Generals (tt0279111) runtime=214'
answers['3'] = 'Winnie the Pooh (tt1449283) runtime 63'
answers['4'] = '109.66 те 110'
answers['5'] = '107.0'

answers['6'] = 'Avatar (tt0499549) profit=2544505847'
answers['7'] = 'The Lone Ranger (tt1210819) profit=-165710090'
answers['8'] = '1478'
answers['9'] = 'The Dark Knight (tt0468569) revenue=1001921825'
answers['10'] = 'The Lone Ranger (tt1210819) profit=-165710090 release_year=2013'

answers['11'] = 'Drama=782'
answers['12'] = 'Drama (560 times)'
answers['13'] = 'Peter Jackson =6490593685'
answers['14'] = 'Robert Rodriguez =9'
answers['15'] = 'Chris Hemsworth =2027450773'
answers['16'] = 'Matt Damon =18'
answers['17'] = 'Action =17'

answers['18'] = 'K-19: The Widowmaker =-64831034'
answers['19'] = '2015 =25449202382'
answers['20'] = '2014 =2295464519'
answers['21'] = 'Сентябрь(09) =227'
answers['22'] = '450'

answers['23'] = 'Peter Jackson =7'
answers['24'] = 'Four By Two Productions =83'
answers['25'] = ''
answers['26'] = 'Inside Out, The Dark Knight, 12 Years a Slave '
answers['27'] = ''


# тут другие ваши предобработки колонок например:

#6 profit = revenue - budget
data['profit'] = data.revenue - data.budget  #Считает прибыль


#14
def counter(movie_bd, x):                    #Раздельный подсчет
    data_plot = movie_bd[x].str.cat(sep = '|')
    dat = pd.Series(data_plot.split('|'))
    info = dat.value_counts(ascending=False)
    return info 

#15
def actor_revenue(df):                       #Раздельный подсчет актеров и прибыли
    summ = Counter()
    for i in range(len(df)):
        for j in df.iloc[i].cast.split('|'):
            summ[j] += df.iloc[i].revenue
    return pd.DataFrame.from_dict(summ, orient='index', columns = ['Summ'])  

#21
def month_to_season(month):                  #Выделение месяцев и деление их на сезоны
    seasons = {
        12: 'winter',
        1: 'winter',
        2: 'winter',
        3: 'spring',
        4: 'spring',
        5: 'spring',
        6: 'summer',
        7: 'summer',
        8: 'summer',
        9: 'autumn',
        10: 'autumn',
        11: 'autumn',
    }
    return seasons[month] 

#23
def directors(row):
    for director in row.director.split('|'):
        return director, row.season


#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него

# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)=380000000'
# запишите свой вариант ответа
answers['1'] = '...'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data.budget.max()
data[(data.budget == 380000000)]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '...'

# %%
data.runtime.max()
data[(data.runtime == 214)]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  gods and generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year  title_length  tagline_length    profit
# 1157           5.8          2003            17              35 -43076064

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
data.runtime.min()
data[(data.runtime == 63)]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  winnie the pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year  title_length  tagline_length  \
# 768    4/13/2011           6.8          2011            15               8
#
#        profit
# 768 -15540000

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
display(data[data.profit == data.profit.max()])
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year  title_length  tagline_length      profit
# 239           7.1          2009             6              27  2544505847

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
display(data[data.profit == data.profit.min()])
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  the lone ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year  title_length  tagline_length     profit
# 1245           6.0          2013            15              23 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
len(data[(data.revenue > data.budget)])
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
data[(data.release_year == 2008)].revenue.max()
data[(data.revenue == 1001921825)]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  the dark knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year  title_length  tagline_length     profit
# 599           8.1          2008            15              15  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
data[(data.profit == data.profit.min()) & (data.release_year>2012) & (data.release_year<2015)]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  the lone ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year  title_length  tagline_length     profit
# 1245           6.0          2013            15              23 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
pd.DataFrame(data.genres.str.split('|').tolist()).stack().value_counts().head(5) 
#Выделение жанров в случае нескольких, создание списка жанров, подсчет, топ 5(не топ 1, что бы проверить, что топ 1- наибольший)
#Далее опущу подобные описания


# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
# Out:
# Drama        782
# Comedy       683
# Thriller     596
# Action       582
# Adventure    415
# dtype: int64

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
pd.DataFrame(data[data.profit > 0].genres.str.split('|').tolist()).stack().value_counts().head(1)
# Out:
# Drama    560
# dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
group_dir=data.groupby(['director'])['revenue'].sum().sort_values(ascending=False)
print(group_dir)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 957, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
sum_gen = counter(data[data['genres'].map(lambda x: True if 'Action' in x else False)],'director')
print(sum_gen)
# Out:
# Robert Rodriguez      9
# Michael Bay           7
# Paul W.S. Anderson    7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Philip G. Atwell      1
# Neil Burger           1
# Henry Selick          1
# Howard McCain         1
# Noam Murro            1
# Length: 364, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
display(actor_revenue(data[data.release_year == 2012]).sort_values(by = ['Summ'], ascending = False))
# Out:
#                          Summ
# Chris Hemsworth    2027450773
# Denis Leary        1629460639
# Anne Hathaway      1522851057
# Robert Downey Jr.  1519557910
# Mark Ruffalo       1519557910
# ...                       ...
# Jason Bateman         3428048
# Nicolas Cage          2106557
# Sami Gayle            2106557
# Josh Lucas            2106557
# Danny Huston          2106557
#
# [466 rows x 1 columns]

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
pd.DataFrame(data[data.budget > data.budget.mean()].cast.str.split('|').tolist()).stack().value_counts().head(5)
# Out:
# Matt Damon        18
# Adam Sandler      17
# Angelina Jolie    16
# Tom Cruise        15
# Eddie Murphy      15
# dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
count_genres = Counter()
for x in data.loc[data['cast'].map(lambda x: True if 'Nicolas Cage' in x else False)]['genres'].str.split('|'): #Выделяем нужного актера
    count_genres += Counter(x)  #Добавляем +1 если подходит под условия
display(count_genres.most_common())
# Out:
# [('Action', 17),
#  ('Thriller', 15),
#  ('Drama', 12),
#  ('Crime', 10),
#  ('Fantasy', 8),
#  ('Adventure', 7),
#  ('Comedy', 6),
#  ('Science Fiction', 4),
#  ('Mystery', 3),
#  ('Animation', 3),
#  ('Family', 3),
#  ('History', 2),
#  ('War', 1),
#  ('Horror', 1),
#  ('Romance', 1)]

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
import collections
loss = collections.Counter()
for i in range(0, len(data)):
    if 'Paramount Pictures' in data['production_companies'].iloc[i]: #Выбираем нужную компанию
        loss[data['original_title'].iloc[i]]+=data.iloc[i]['profit'] #Считаем прибыль и смотрим в конец списка
print(loss)
# Out:
# Counter({'transformers: dark of the moon': 928746996, 'transformers: revenge of the fallen': 686297228, 'indiana jones and the kingdom of the crystal skull': 601636033, 'transformers': 559709780, 'mission: impossible - ghost protocol': 549713380, 'mission: impossible - rogue nation': 532330139, 'war of the worlds': 459739379, 'interstellar': 456752480, 'mission: impossible ii': 421388105, 'teenage mutant ninja turtles': 352200000, 'world war z': 331865000, 'what women want': 304111707, 'the wolf of wall street': 292000694, 'terminator genisys': 285603537, 'star trek into darkness': 277365246, 'mission: impossible iii': 247850012, 'the adventures of tintin': 241940071, 'noah': 237637473, 'the spongebob movie: sponge out of water': 237594032, 'star trek': 235680446, 'shutter island': 214804195, 'true grit': 214276927, 'little fockers': 210650585, 'super 8': 210095987, 'paranormal activity 3': 200703818, "daddy's home": 190360392, 'the curious case of benjamin button': 183932083, 'hanse
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
data.groupby(['release_year'])[['revenue']].sum().stack().sort_values(ascending = False)
# Out:
# release_year
# 2015          revenue    25449202382
# 2014          revenue    23405862953
# 2013          revenue    23213799791
# 2012          revenue    23079001687
# 2011          revenue    22676791872
# 2010          revenue    21071204961
# 2009          revenue    20261791024
# 2008          revenue    18252781990
# 2007          revenue    18162406801
# 2004          revenue    15663430720
# 2005          revenue    15309425558
# 2006          revenue    14775042320
# 2003          revenue    14346123312
# 2002          revenue    14136361487
# 2001          revenue    13017764865
# 2000          revenue    10664099805
# dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
import collections
wb = collections.Counter()
for i in range(0, len(data)):
    if 'Warner Bros' in data['production_companies'].iloc[i]:
        wb[data['release_year'].iloc[i]] += data.iloc[i]['profit']
print(wb)
# Out:
# Counter({2014: 2295464519, 2007: 2201675217, 2008: 2134595031, 2010: 1974712985, 2011: 1871393682, 2003: 1855493377, 2009: 1822454136, 2013: 1636453400, 2004: 1631933725, 2005: 1551980298, 2001: 1343545668, 2012: 1258020056, 2002: 1022709901, 2015: 870368348, 2006: 620170743, 2000: 452631386})

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
df = data.copy()

df['release_month'] = pd.to_datetime(df.release_date).apply(lambda x: x.month)
df['season'] = df.release_month.apply(month_to_season)
df.groupby(['release_month']).nunique() #Смотрим на imdb_id и выбираем большее число
# Out:
#                imdb_id  budget  revenue  original_title  cast  director  \
# release_month
# 1                  110      45      110             110   110       105
# 2                  135      54      135             135   135       121
# 3                  156      74      156             156   156       137
# 4                  149      66      149             149   149       137
# 5                  140      77      140             140   137       127
# 6                  147      68      147             147   147       127
# 7                  142      66      142             142   142       122
# 8                  161      65      161             161   161       147
# 9                  227      70      227             227   227       192
# 10                 186      67      186             186   186       163
# 11                 146      65      146             146   145       134
# 12                 190      80      190             190   187       145
#
# ...

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
df = data.copy()

df['release_month'] = pd.to_datetime(df.release_date).apply(lambda x: x.month)
df.groupby(['release_month']).nunique() #Сумируем imdb_id за 6,7,8 месяцы
# Out:
#                imdb_id  budget  revenue  original_title  cast  director  \
# release_month
# 1                  110      45      110             110   110       105
# 2                  135      54      135             135   135       121
# 3                  156      74      156             156   156       137
# 4                  149      66      149             149   149       137
# 5                  140      77      140             140   137       127
# 6                  147      68      147             147   147       127
# 7                  142      66      142             142   142       122
# 8                  161      65      161             161   161       147
# 9                  227      70      227             227   227       192
# 10                 186      67      186             186   186       163
# 11                 146      65      146             146   145       134
# 12                 190      80      190             190   187       145
#
# ...

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
df = data.copy()


df['release_month'] = pd.to_datetime(df.release_date).apply(lambda x: x.month)
df['season'] = df.release_month.apply(month_to_season)

df = pd.DataFrame(df.apply(directors, axis=1).tolist(), columns = ['director', 'season'])
df['count'] = 1
df = pd.pivot_table(df, index = 'director', columns = 'season', values = 'count', aggfunc = 'sum')
df.sort_values('winter', ascending = False)
# Out:
# season             autumn  spring  summer  winter
# director
# Peter Jackson         1.0     NaN     NaN     7.0
# Steven Soderbergh     3.0     2.0     2.0     6.0
# Clint Eastwood        4.0     NaN     2.0     6.0
# Shawn Levy            3.0     2.0     1.0     4.0
# Adam Shankman         NaN     2.0     2.0     4.0
# ...                   ...     ...     ...     ...
# Wong Kar-wai          NaN     1.0     NaN     NaN
# Woody Allen           NaN     1.0     2.0     NaN
# Xavier Gens           1.0     NaN     NaN     NaN
# Zack Snyder           NaN     4.0     2.0     NaN
# Zal Batmanglij        NaN     1.0     NaN     NaN
#
# [925 rows x 4 columns]

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
data['title_length'] = data['original_title'].map(lambda x: len(x))

sum_gen = counter(data,'production_companies')
for gen in sum_gen.index:
    sum_gen[gen] = data['title_length'][data['production_companies'].map(lambda x: True if gen in x else False)].mean() 
sum_gen = pd.DataFrame(sum_gen).sort_values(0, ascending = False)

display(sum_gen)
# Out:
#                              0
# Four By Two Productions     83
# Jim Henson Company, The     59
# Dos Corazones               47
# Polsky Films                46
# Museum Canada Productions   46
# ...                         ..
# Berlanti Productions         3
# Everest Entertainment        3
# Ixtlan Productions           2
# Global Entertainment Group   2
# XM2 Productions              2
#
# [1771 rows x 1 columns]

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
data[data['vote_average'] > data.quantile(0.99, numeric_only = True)['vote_average']] #Далее сравниваем с нужными вариантами в ответе
# Out:
#         imdb_id     budget     revenue  \
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 119   tt2015381  170000000   773312399
# 125   tt2084970   14000000   233555708
# 128   tt2267998   61000000   369330363
# 138   tt2278388   30000000   174600318
# 370   tt1375666  160000000   825500000
# 599   tt0468569  185000000  1001921825
# 872   tt0253474   35000000   120072577
# 1081  tt0167260   94000000  1118888979
# 1183  tt0993846  100000000   392000694
# 1191  tt2024544   20000000   187000000
# 1800  tt0209144    9000000    39723096
#
#                                      original_title  \
# 9                                        inside out
# 34                                             room
# 118                                    interstellar
# 119                         guardians of the galaxy
# 125                              the imitation game
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '...',
#  '2': '...',
#  '3': 'Winnie the Pooh (tt1449283) runtime 63',
#  '4': '109.66 те 110',
#  '5': '107.0',
#  '6': 'Avatar (tt0499549) profit=2544505847',
#  '7': 'The Lone Ranger (tt1210819) profit=-165710090',
#  '8': '1478',
#  '9': 'The Dark Knight (tt0468569) revenue=1001921825',
#  '10': 'The Lone Ranger (tt1210819) profit=-165710090 release_year=2013',
#  '11': 'Drama=782',
#  '12': 'Drama (560 times)',
#  '13': 'Peter Jackson =6490593685',
#  '14': 'Robert Rodriguez =9',
#  '15': 'Chris Hemsworth =2027450773',
#  '16': 'Matt Damon =18',
#  '17': 'Action =17',
#  '18': 'K-19: The Widowmaker =-64831034',
#  '19': '2015 =25449202382',
#  '20': '2014 =2295464519',
#  '21': 'Сентябрь(09) =227',
#  '22': '450',
#  '23': 'Peter Jackson =7',
#  '24': 'Four By Two Productions =83',
#  '25': '',
#  '26': 'Inside Out, The Dark Knight, 12 Years a Slave ',
#  '27': ''}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
